# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
with open("wav_greater_than_5_2018-01-16-06-24.b", "rb") as f:
    durations = pickle.load(f)

# %%
len(durations)
# Out:
# 83221

# %%
df = pd.DataFrame(data=durations,columns=["sec"])

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5ba0d81cd0>]], dtype=object)

# %%
sns.distplot(df, bins=10)

# %%
def bins_labels(bins, **kwargs):
    bin_w = (max(bins) - min(bins)) / (len(bins) - 1)
    plt.xticks(np.arange(min(bins)+bin_w/2, max(bins), bin_w), bins, **kwargs)
    plt.xlim(bins[0], bins[-1])

# %%
plt.hist(df["sec"], bins=5)
plt.show()
# [   0-5,   5-10,   10-15, 15-20, 20-25]
# [ 74287,   8768,     153,    12,     1]
